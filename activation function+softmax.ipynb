# %%
from IPython.display import Latex, HTML

# %% [markdown]
# ## Warm up

# %% [markdown]
#   $a = b + c$

# %% [markdown]
# $$c = \sqrt{a^2 + b^2}$$

# %% [markdown]
# ## More examples

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Most popular types of activation functions in ML (hidden layer)

# %% [markdown]
# **1)Sigmoid or Logistic**

# %%
#$ S(x)={\frac {1}{1+e^{-x}}}={\frac {e^{x}}{e^{x}+1}}$

# %% [markdown]
# <strong> $ S(x)={\frac {1}{1+e^{-x}}}={\frac {e^{x}}{e^{x}+1}}$ </strong>

# %% [markdown]
# Note: range from 0 to 1
# <img src="img/sigmoid-1.png" style="height:250px">

# %%
#Python code 1) 

import math

def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
#code 2)

import numpy as np
def sigmoid(x):
    s = 1/(1+np.exp(-x))
    return s

# %% [markdown]
# **2)Tanh or hyperbolic tangent Activation Function**

# %%
#$ f(x)={\frac {2}{1+e^{-2x}}-1}$

# %% [markdown]
# $ f(x)={\frac {2}{1+e^{-2x}}-1}$

# %% [markdown]
# Note:range -1 to 1
# <img src="img/tanh.png" style="height:300px">

# %%
#python code:

def tanh(x, derivative=False):
    if (derivative==True):
        return(1-(X**2))
    return np.tanh(x)

# %% [markdown]
# **3)Relu Function (Rectifier neural networks)**

# %%
#$ f(x)=x^{+}=\max(0,x)$

# %% [markdown]
# $ f(x)=x^{+}=\max(0,x)$

# %% [markdown]
# Note:range 0 to $\infty$
# <img src="img/relu.png" style="height:300px">

# %%
#python code

def relu(x):
    return np.maximum(0,x)

# %% [markdown]
# ## Softmax function for output layer-guess the possibility

# %%
#$ s(yi)={\frac {e^{yi}}{\sum ^{yi}}}$

# %% [markdown]
# $ s(yi)={\frac {e^{yi}}{\sum ^{yi}}}$

# %% [markdown]
# #Note: refer also Wikipedia
#
# <img src="img/softmax.png" style="height:300px">
# https://medium.com/data-science-bootcamp/understand-the-softmax-function-in-minutes-f3a59641e86d

# %%
#python code


logits=[2.0,1.0,0.1]
sum(logits)
# Out:
# 3.1

# %%
import numpy as py
np.exp(0)==1
# Out:
# True

# %%
exps=[np.exp(i)for i in logits]
exps
# Out:
# [7.38905609893065, 2.718281828459045, 1.1051709180756477]

# %%
sum(exps)
# Out:
# 11.212508845465344

# %%
sum_of_exps=sum(exps)
sum_of_exps
# Out:
# 11.212508845465344

# %%
softmax=[j/sum_of_exps for j in exps]
softmax
# Out:
# [0.6590011388859679, 0.2424329707047139, 0.09856589040931818]

# %%
sum(softmax)
# Out:
# 1.0
